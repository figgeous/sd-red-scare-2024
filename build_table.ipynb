# %%
import pandas as pd

def process_files_in_directory(directory_path):
    # Initialize an empty dictionary to store data
    data = {}

    # Loop through each file in the directory
    for filename in os.listdir(directory_path):
        # Only process .txt files
        if filename.endswith('.txt'):
            file_path = os.path.join(directory_path, filename)
            column_name = filename  # Use the filename as the column name
            
            with open(file_path, 'r') as file:
                file_data = {}
                for line in file:
                    # Split line into file entry name and its value
                    entry_name, value = line.strip().split()
                    try:
                        file_data[entry_name] = int(value)
                    except ValueError:
                        file_data[entry_name] = value
            
            # Add this file's data to the main data dictionary under its filename
            data[column_name] = file_data

    # Convert the dictionary of dictionaries to a DataFrame
    df = pd.DataFrame(data).sort_index()

    return df

# Usage example
directory_path = 'results'
df = process_files_in_directory(directory_path)

# %%
df
# Out:
#                        some.txt alternate.txt             many.txt  few.txt  \
# G-ex.txt                   True          true  NegativeWeightCycle      0.0
# P3.txt                     True          true  NegativeWeightCycle      1.0
# bht.txt                    True         false       Timeout_3600_s      0.0
# common-1-100.txt          False         false                   -1     -1.0
# common-1-1000.txt         False         false                   -1     -1.0
# ...                         ...           ...                  ...      ...
# wall-z-1000.txt            True         false                  NaN      0.0
# wall-z-10000.txt   UnknownError         false                  NaN      0.0
# wall-z-2.txt               True         false                  NaN      0.0
# wall-z-3.txt               True         false                  NaN      0.0
# wall-z-4.txt               True         false                  NaN      0.0
#
#                    none.txt
# G-ex.txt                3.0
# P3.txt                 -1.0
# bht.txt                 6.0
# common-1-100.txt       -1.0
# common-1-1000.txt      -1.0
# ...                     ...
# wall-z-1000.txt         1.0
# wall-z-10000.txt        1.0
# wall-z-2.txt            1.0
# wall-z-3.txt            1.0
# wall-z-4.txt            1.0
#
# [156 rows x 5 columns]
